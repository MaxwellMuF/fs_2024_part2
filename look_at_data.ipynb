# %%
import pandas as pd
import core.methods as m1
# Out:
# 2025-01-13 02:41:08.199 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df_dis = pd.read_csv("data/datasets/Ladesaeulenregister.csv", sep=";")
# df_plz = pd.read_csv("data/datasets/plz_einwohner.csv", sep=",")
# df_vk = pd.read_csv("data/datasets/Verkehrsaufkommen.csv", sep=";")
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_8112\3201622903.py:1: DtypeWarning: Columns (21,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_dis = pd.read_csv("data/datasets/Ladesaeulenregister.csv", sep=";")

# %%
len(df_dis.columns)
# Out:
# 26

# %%
df_tt = df_dis[df_dis["Bundesland"] == "Italy"].copy()
len(df_tt)
# Out:
# 0

# %%
df_tt.loc[0,:] = [None]*len(df_tt.columns)

# %%
df_tt.round({"Postleitzahl":0})
# Out:
# Empty DataFrame
# Columns: [Betreiber, Straße, Hausnummer, Adresszusatz, Postleitzahl, Ort, Bundesland, Kreis/kreisfreie Stadt, Breitengrad, Längengrad, Inbetriebnahmedatum, Nennleistung Ladeeinrichtung [kW], Art der Ladeeinrichung, Anzahl Ladepunkte, Steckertypen1, P1 [kW], Public Key1, Steckertypen2, P2 [kW], Public Key2, Steckertypen3, P3 [kW], Public Key3, Steckertypen4, P4 [kW], Public Key4]
# Index: []
#
# [0 rows x 26 columns]

# %%
df_dis["Nennleistung Ladeeinrichtung [kW]"]
# Out:
# 0         22
# 1         22
# 2         22
# 3         93
# 4         22
#         ...
# 69381     44
# 69382     44
# 69383     30
# 69384    NaN
# 69385    NaN
# Name: Nennleistung Ladeeinrichtung [kW], Length: 69386, dtype: object

# %%
df_dis[df_dis["Nennleistung Ladeeinrichtung [kW]"] != None]
# Out:
#                                      Betreiber                  Straße  \
# 0                        Albwerk GmbH & Co. KG          Ennabeurer Weg
# 1                                        smopi               Albstraße
# 2                        Albwerk GmbH & Co. KG  Parkplatz Campingplatz
# 3                 EnBW mobility+ AG und Co.KG              Hauptstraße
# 4                             SWU Energie GmbH              Sterngasse
# ...                                        ...                     ...
# 69381  Stadtwerke Weimar Stadtversorgungs-GmbH        Wunderwaldstraße
# 69382                                      eva               Lachenweg
# 69383                          TEAG Mobil GmbH          Sulzaer Straße
# 69384                                      NaN                     NaN
# 69385                                      NaN                     NaN
#
#       Hausnummer Adresszusatz  Postleitzahl           Ort         Bundesland  \
# ...

# %%
dframe3                 = df_dis[(df_dis["Postleitzahl"] > 10000) &  (df_dis["Postleitzahl"] < 14200)]

# %%
dframe3[dframe3["Nennleistung Ladeeinrichtung [kW]"] != None].loc[26556]
# Out:
# Betreiber                            Design Offices GmbH (Köln)
# Straße                                             Gartenstraße
# Hausnummer                                                   87
# Adresszusatz                                                NaN
# Postleitzahl                                            10115.0
# Ort                                                      Berlin
# Bundesland                                               Berlin
# Kreis/kreisfreie Stadt                  Kreisfreie Stadt Berlin
# Breitengrad                                          52,5327098
# Längengrad                                           13,3883113
# Inbetriebnahmedatum                                  25.07.2022
# Nennleistung Ladeeinrichtung [kW]                            22
# Art der Ladeeinrichung                    Normalladeeinrichtung
# Anzahl Ladepunkte                                           1.0
# Steckertypen1                                AC Steckdose Typ 2
# ...

# %%
dframe3["Nennleistung Ladeeinrichtung [kW]"].unique()
# Out:
# array(['22', '30', '44', '175', '11', '3,7', '93', '150', '50', '300',
#        '72', '75', '144', '320', '600', '77', '39,6', '42', '52', '180',
#        '24', '88', '350', '360', '66', '250', '43', '97', '92', '6',
#        '39,65', '120', '13,2', '156', '160', '96', '122', '132', '184',
#        '225', '100'], dtype=object)

# %%
dframe3[dframe3["Postleitzahl"] == 10115].loc[26555:26559]["P1 [kW]"]
# Out:
# 26555    11
# 26556    22
# 26557    22
# 26558    22
# 26559    22
# Name: P1 [kW], dtype: object

# %%
sorted(dframe3["Nennleistung Ladeeinrichtung [kW]"].unique())
# Out:
# ['100',
#  '11',
#  '120',
#  '122',
#  '13,2',
#  '132',
#  '144',
#  '150',
#  '156',
#  '160',
#  '175',
#  '180',
#  '184',
#  '22',
#  '225',
#  '24',
#  '250',
#  '3,7',
#  '30',
#  '300',
#  '320',
#  '350',
#  '360',
#  '39,6',
#  '39,65',
#  '42',
#  '43',
#  '44',
#  '50',
#  '52',
#  '6',
#  '600',
#  '66',
#  '72',
#  '75',
#  '77',
#  '88',
#  '92',
#  '93',
#  '96',
#  '97']

# %%
dframe3[dframe3["Bundesland"] != "Berlin"].loc[:,"Bundesland"].to_list()
# Out:
# ['Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Brandenburg',
#  'Hamburg',
#  'Mecklenburg-Vorpommern',
#  'Mecklenburg-Vorpommern']

# %%
"🫓"
# Out:
# '🫓'

# %%
import emoji # Needs 'pip install emoji'

# %%
emoji.emojize(":check_mark:",language='alias'), emoji.emojize(":cross_mark:",language='alias')
# Out:
# ('✔️', '❌')

# %%
":cross_mark:"
# Out:
# ':cross_mark:'

# %%
[":coffee:"].apply(lambda x: emoji.emojize(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 [":coffee:"].apply(lambda x: emoji.emojize(x))
#
# AttributeError: 'list' object has no attribute 'apply'

# %%
dframe3[dframe3["Bundesland"].str.contains("Berlin")]
# Out:
#                                       Betreiber                Straße  \
# 26555                Design Offices GmbH (Köln)          Gartenstraße
# 26556                Design Offices GmbH (Köln)          Gartenstraße
# 26557                Design Offices GmbH (Köln)          Gartenstraße
# 26558                Design Offices GmbH (Köln)          Gartenstraße
# 26559                Design Offices GmbH (Köln)          Gartenstraße
# ...                                         ...                   ...
# 29323  Berliner Stadtwerke KommunalPartner GmbH      Warnemünder Str.
# 29324  Berliner Stadtwerke KommunalPartner GmbH          Berkaer Str.
# 29325  Berliner Stadtwerke KommunalPartner GmbH        Kissinger Str.
# 29326  Berliner Stadtwerke KommunalPartner GmbH      Hohenzollerndamm
# 29327                 E.ON Drive Infrastructure  Fritz-Wildung-Straße
#
#       Hausnummer Adresszusatz  Postleitzahl     Ort Bundesland  \
# ...

# %%
"Hallo \
Du"
# Out:
# 'Hallo Du'

# %%
df_dis[df_dis["Nennleistung Ladeeinrichtung [kW]"] != None]

# %%
df_plz
# Out:
#         plz                                          note  einwohner  \
# 0      1067                                 01067 Dresden      11957
# 1      1069                                 01069 Dresden      25483
# 2      1097                                 01097 Dresden      14821
# 3      1099                                 01099 Dresden      28018
# 4      1108                                 01108 Dresden       5876
# ...     ...                                           ...        ...
# 8165  99988                            99988 Südeichsfeld       4866
# 8166  99991                         99991 Unstrut-Hainich       5269
# 8167  99994  99994 Marolterode, Nottertal-Heilinger Höhen       6384
# 8168  99996                              99996 Unstruttal       6751
# 8169  99998                      99998 Körner, Weinbergen       4942
#
#              qkm       lat       lon
# 0       6.866839  51.06019  13.71117
# 1       5.339213  51.03964  13.73030
# ...

# %%
df_vk
# Out:
#       Technischer Schlüssel            Link-ID        Detailnetz-Nr.  \
# 0                       506  40520002_40520068  40520002_40520068.01
# 1                      1426  57590018_57590019  57590018_57590019.02
# 2                      1506  45540043_T0023560  45540043_45530010.01
# 3                      1596  37480003_T0024150  37480003_37470026.01
# 4                      1711  38520058_38520059  38520058_38520059.02
# ...                     ...                ...                   ...
# 9917                   9917  49580045_49580043  49580045_49580043.01
# 9918                   9918  49480019_49480043  49480019_49480043.02
# 9919                   9919  38550010_38550012  38550010_38550012.02
# 9920                   9921  38520065_38520051  38520065_38520051.02
# 9921                   9922  48480021_48480020  48480021_48480020.01
#
#            VP_von       VP_bis Von-Station Bis-Station Verkehrsrichtung  \
# ...

# %%
import numpy as np
import pandas as pd

# %%
available_station_value = np.random.choice([True,False], 100)

# %%
available_station = [{f"is_widget": value} for value in available_station_value.tolist()]

# %%
available_station_value
# Out:
# array([False, False, False,  True, False,  True, False, False,  True,
#        False,  True,  True, False,  True, False, False,  True, False,
#         True,  True, False,  True,  True, False, False,  True,  True,
#        False, False,  True, False,  True,  True, False, False, False,
#         True, False, False,  True,  True, False, False,  True,  True,
#         True,  True,  True, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False,  True,
#        False,  True,  True,  True, False,  True, False,  True,  True,
#        False, False,  True, False,  True, False, False, False, False,
#        False,  True,  True, False, False,  True,  True,  True,  True,
#        False, False,  True, False, False, False, False, False, False,
#         True])

# %%
available_station
# Out:
# [{'is_widget': False},
#  {'is_widget': False},
#  {'is_widget': False},
#  {'is_widget': True},
#  {'is_widget': False},
#  {'is_widget': True},
#  {'is_widget': False},
#  {'is_widget': False},
#  {'is_widget': True},
#  {'is_widget': False},
#  {'is_widget': True},
#  {'is_widget': True},
#  {'is_widget': False},
#  {'is_widget': True},
#  {'is_widget': False},
#  {'is_widget': False},
#  {'is_widget': True},
#  {'is_widget': False},
#  {'is_widget': True},
#  {'is_widget': True},
#  {'is_widget': False},
#  {'is_widget': True},
#  {'is_widget': True},
#  {'is_widget': False},
#  {'is_widget': False},
#  {'is_widget': True},
#  {'is_widget': True},
#  {'is_widget': False},
#  {'is_widget': False},
#  {'is_widget': True},
#  {'is_widget': False},
#  {'is_widget': True},
#  {'is_widget': True},
#  {'is_widget': False},
#  {'is_widget': False},
#  {'is_widget': False},
#  {'is_widget': True},
#  {'is_widget': False},
#  {'is_widget': False},
#  {'is_widget': True},
# ...

# %%
df_av = pd.DataFrame(available_station)

# %%
pd.concat([df_av,df_av], axis=1)
# Out:
#     is_widget  is_widget
# 0       False      False
# 1       False      False
# 2       False      False
# 3        True       True
# 4       False      False
# ..        ...        ...
# 95      False      False
# 96      False      False
# 97      False      False
# 98      False      False
# 99       True       True
#
# [100 rows x 2 columns]

# %%
df_av.shape
# Out:
# (100, 1)

# %%
import json

# %%
try:
    with open("DataBase_user_changes.json", "r") as file:
            user_database = json.load(file)
except:
    with open("DataBase_user_changes.json", "w") as file:
         json.dump({}, file)
user_database
# Out:
# {}

# %%
user_database["test1"] = {"testes": "case", "other":"stuff"}
with open("DataBase_user_changes.json", "w") as file:
         json.dump(user_database, file)

# %%
df = pd.DataFrame(user_database)

# %%
df.columns
# Out:
# Index(['test', 'test1'], dtype='object')

# %%
df2 = pd.DataFrame(columns=df.columns)

# %%
df2.loc[3,:] = [2,3]

# %%
df2
# Out:
#   test test1
# 0    2     3
# 1    2     3
# 3    2     3

# %%
import datetime

# %%
datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S") #.time()
# Out:
# '2025-01-09 17:29:08'

# %%
df2.columns.to_list() + ["Comment", "Rating"]
# Out:
# ['test', 'test1', 'Comment', 'Rating']

# %%
list(range(1,6))
# Out:
# [1, 2, 3, 4, 5]
