# %%
import pandas as pd
import core.methods as m1
# Out:
# 2025-01-08 18:07:01.852 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df_dis = pd.read_csv("data/datasets/Ladesaeulenregister.csv", sep=";")
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_19680\220514790.py:1: DtypeWarning: Columns (4,13,21,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_dis = pd.read_csv("data/datasets/Ladesaeulenregister.csv", sep=";")

# %%
# df_dis.drop([i for i in range(9)], axis=0, inplace=True)
df_dis.loc[9]
# Out:
# Ladesäulenregister Bundesnetzagentur                            Betreiber
# Unnamed: 1                                                         Straße
# Unnamed: 2                                                     Hausnummer
# Unnamed: 3                                                   Adresszusatz
# Unnamed: 4                                                   Postleitzahl
# Unnamed: 5                                                            Ort
# Unnamed: 6                                                     Bundesland
# Unnamed: 7                                         Kreis/kreisfreie Stadt
# Unnamed: 8                                                    Breitengrad
# Unnamed: 9                                                     Längengrad
# Unnamed: 10                                           Inbetriebnahmedatum
# Unnamed: 11                             Nennleistung Ladeeinrichtung [kW]
# Unnamed: 12                                        Art der Ladeeinrichung
# Unnamed: 13                                             Anzahl Ladepunkte
# Unnamed: 14                                                 Steckertypen1
# Unnamed: 15                                                       P1 [kW]
# Unnamed: 16                                                   Public Key1
# Unnamed: 17                                                 Steckertypen2
# Unnamed: 18                                                       P2 [kW]
# Unnamed: 19                                                   Public Key2
# Unnamed: 20                                                 Steckertypen3
# Unnamed: 21                                                       P3 [kW]
# Unnamed: 22                                                   Public Key3
# Unnamed: 23                                                 Steckertypen4
# Unnamed: 24                                                       P4 [kW]
# Unnamed: 25                                                   Public Key4
# Name: 9, dtype: object

# %%
df_dis
# Out:
#                     Ladesäulenregister Bundesnetzagentur        Unnamed: 1  \
# 0                                                    NaN               NaN
# 1                                              Hinweis:                NaN
# 2      Die Liste beinhaltet die Ladeeinrichtungen all...               NaN
# 3      zum Zeitpunkt der Aktualisierung vollständig a...               NaN
# 4      Die Zahl der öffentlich zugänglichen Ladeeinri...               NaN
# ...                                                  ...               ...
# 69391            Stadtwerke Weimar Stadtversorgungs-GmbH  Wunderwaldstraße
# 69392                                                eva         Lachenweg
# 69393                                    TEAG Mobil GmbH    Sulzaer Straße
# 69394                                                NaN               NaN
# 69395                                                NaN               NaN
#
#       Unnamed: 2 Unnamed: 3 Unnamed: 4    Unnamed: 5 Unnamed: 6  \
# 0            NaN        NaN        NaN           NaN        NaN
# 1            NaN        NaN        NaN           NaN        NaN
# 2            NaN        NaN        NaN           NaN        NaN
# 3            NaN        NaN        NaN           NaN        NaN
# 4            NaN        NaN        NaN           NaN        NaN
# ...          ...        ...        ...           ...        ...
# 69391         2a        NaN    99518.0     Bad Sulza  Thüringen
# 69392         13        NaN    99518.0     Bad Sulza  Thüringen
# 69393          0        NaN    99518.0  Großheringen  Thüringen
# 69394        NaN        NaN        NaN           NaN        NaN
# 69395        NaN        NaN        NaN           NaN        NaN
#
#                     Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0                          NaN        NaN        NaN  ...
# 1                          NaN        NaN        NaN  ...
# 2                          NaN        NaN        NaN  ...
# 3                          NaN        NaN        NaN  ...
# 4                          NaN        NaN        NaN  ...
# ...                        ...        ...        ...  ...
# 69391  Landkreis Weimarer Land  51,092527  11,628574  ...
# 69392  Landkreis Weimarer Land  51,096202  11,628901  ...
# 69393  Landkreis Weimarer Land  51,107188  11,659489  ...
# 69394                      NaN        NaN        NaN  ...
# 69395                      NaN        NaN        NaN  ...
#
#                                              Unnamed: 16         Unnamed: 17  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 2                                                    NaN                 NaN
# 3                                                    NaN                 NaN
# 4                                                    NaN                 NaN
# ...                                                  ...                 ...
# 69391                                                NaN  AC Steckdose Typ 2
# 69392                                                NaN  AC Steckdose Typ 2
# 69393  3059301306072A8648CE3D020106082A8648CE3D030107...  AC Steckdose Typ 2
# 69394                                                NaN                 NaN
# 69395                                                NaN                 NaN
#
#       Unnamed: 18                                        Unnamed: 19  \
# 0             NaN                                                NaN
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4             NaN                                                NaN
# ...           ...                                                ...
# 69391          22                                                NaN
# 69392          22                                                NaN
# 69393          22  3059301306072A8648CE3D020106082A8648CE3D030107...
# 69394         NaN                                                NaN
# 69395         NaN                                                NaN
#
#       Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25
# 0             NaN         NaN         NaN         NaN         NaN         NaN
# 1             NaN         NaN         NaN         NaN         NaN         NaN
# 2             NaN         NaN         NaN         NaN         NaN         NaN
# 3             NaN         NaN         NaN         NaN         NaN         NaN
# 4             NaN         NaN         NaN         NaN         NaN         NaN
# ...           ...         ...         ...         ...         ...         ...
# 69391         NaN         NaN         NaN         NaN         NaN         NaN
# 69392         NaN         NaN         NaN         NaN         NaN         NaN
# 69393         NaN         NaN         NaN         NaN         NaN         NaN
# 69394         NaN         NaN         NaN         NaN         NaN         NaN
# 69395         NaN         NaN         NaN         NaN         NaN         NaN
#
# [69396 rows x 26 columns]

# %%
df_dis.head(10)
# Out:
#                 Ladesäulenregister Bundesnetzagentur Unnamed: 1  Unnamed: 2  \
# 0                                                NaN        NaN         NaN
# 1                                          Hinweis:         NaN         NaN
# 2  Die Liste beinhaltet die Ladeeinrichtungen all...        NaN         NaN
# 3  zum Zeitpunkt der Aktualisierung vollständig a...        NaN         NaN
# 4  Die Zahl der öffentlich zugänglichen Ladeeinri...        NaN         NaN
# 5                                                NaN        NaN         NaN
# 6              Letzte Aktualisierung vom: 16.07.2024        NaN         NaN
# 7                                                NaN        NaN         NaN
# 8                           Allgemeine Informationen        NaN         NaN
# 9                                          Betreiber     Straße  Hausnummer
#
#      Unnamed: 3    Unnamed: 4 Unnamed: 5  Unnamed: 6              Unnamed: 7  \
# 0           NaN           NaN        NaN         NaN                     NaN
# 1           NaN           NaN        NaN         NaN                     NaN
# 2           NaN           NaN        NaN         NaN                     NaN
# 3           NaN           NaN        NaN         NaN                     NaN
# 4           NaN           NaN        NaN         NaN                     NaN
# 5           NaN           NaN        NaN         NaN                     NaN
# 6           NaN           NaN        NaN         NaN                     NaN
# 7           NaN           NaN        NaN         NaN                     NaN
# 8           NaN           NaN        NaN         NaN                     NaN
# 9  Adresszusatz  Postleitzahl        Ort  Bundesland  Kreis/kreisfreie Stadt
#
#     Unnamed: 8  Unnamed: 9  ...  Unnamed: 16    Unnamed: 17 Unnamed: 18  \
# 0          NaN         NaN  ...          NaN            NaN         NaN
# 1          NaN         NaN  ...          NaN            NaN         NaN
# 2          NaN         NaN  ...          NaN            NaN         NaN
# 3          NaN         NaN  ...          NaN            NaN         NaN
# 4          NaN         NaN  ...          NaN            NaN         NaN
# 5          NaN         NaN  ...          NaN            NaN         NaN
# 6          NaN         NaN  ...          NaN            NaN         NaN
# 7          NaN         NaN  ...          NaN            NaN         NaN
# 8          NaN         NaN  ...          NaN   2. Ladepunkt         NaN
# 9  Breitengrad  Längengrad  ...  Public Key1  Steckertypen2     P2 [kW]
#
#    Unnamed: 19    Unnamed: 20 Unnamed: 21  Unnamed: 22    Unnamed: 23  \
# 0          NaN            NaN         NaN          NaN            NaN
# 1          NaN            NaN         NaN          NaN            NaN
# 2          NaN            NaN         NaN          NaN            NaN
# 3          NaN            NaN         NaN          NaN            NaN
# 4          NaN            NaN         NaN          NaN            NaN
# 5          NaN            NaN         NaN          NaN            NaN
# 6          NaN            NaN         NaN          NaN            NaN
# 7          NaN            NaN         NaN          NaN            NaN
# 8          NaN   3. Ladepunkt         NaN          NaN   4. Ladepunkt
# 9  Public Key2  Steckertypen3     P3 [kW]  Public Key3  Steckertypen4
#
#   Unnamed: 24  Unnamed: 25
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN
# 3         NaN          NaN
# 4         NaN          NaN
# 5         NaN          NaN
# 6         NaN          NaN
# 7         NaN          NaN
# 8         NaN          NaN
# 9     P4 [kW]  Public Key4
#
# [10 rows x 26 columns]
